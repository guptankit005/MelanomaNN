# %% [markdown]
# **Importing Important Libraries**

# %%
import pathlib
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# **Importing Data**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Create  dataset**

# %%
#defining some parameters
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# **Visualizing The Data**

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Create the model**

# %% [markdown]
#  Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
num_classes = 9

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 2s 32ms/step - loss: 2.0149 - accuracy: 0.2333 - val_loss: 1.8831 - val_accuracy: 0.3199
# Epoch 2/20
# 56/56 [==============================] - 2s 30ms/step - loss: 1.8231 - accuracy: 0.3214 - val_loss: 1.7124 - val_accuracy: 0.4049
# Epoch 3/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.7455 - accuracy: 0.3666 - val_loss: 1.7747 - val_accuracy: 0.3356
# Epoch 4/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.6527 - accuracy: 0.4001 - val_loss: 1.6237 - val_accuracy: 0.3915
# Epoch 5/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.5053 - accuracy: 0.4660 - val_loss: 1.4267 - val_accuracy: 0.5235
# Epoch 6/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.4210 - accuracy: 0.4972 - val_loss: 1.4475 - val_accuracy: 0.5011
# Epoch 7/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.4253 - accuracy: 0.5033 - val_loss: 1.3782 - val_accuracy: 0.5302
# Epoch 8/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.3770 - accuracy: 0.5145 - val_loss: 1.3757 - val_accuracy: 0.5235
# Epoch 9/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2789 - accuracy: 0.5513 - val_loss: 1.3920 - val_accuracy: 0.4922
# Epoch 10/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2752 - accuracy: 0.5262 - val_loss: 1.3589 - val_accuracy: 0.5190
# Epoch 11/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1976 - accuracy: 0.5614 - val_loss: 1.3606 - val_accuracy: 0.5324
# Epoch 12/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1612 - accuracy: 0.5831 - val_loss: 1.6159 - val_accuracy: 0.4430
# Epoch 13/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2054 - accuracy: 0.5497 - val_loss: 1.3808 - val_accuracy: 0.5213
# Epoch 14/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.1188 - accuracy: 0.5882 - val_loss: 1.3623 - val_accuracy: 0.5369
# Epoch 15/20
# 56/56 [==============================] - 2s 28ms/step - loss: 1.0387 - accuracy: 0.6144 - val_loss: 1.4085 - val_accuracy: 0.5459
# Epoch 16/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.0108 - accuracy: 0.6295 - val_loss: 1.5202 - val_accuracy: 0.5324
# Epoch 17/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.9665 - accuracy: 0.6390 - val_loss: 1.4692 - val_accuracy: 0.5548
# Epoch 18/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.8612 - accuracy: 0.6925 - val_loss: 1.6121 - val_accuracy: 0.4609
# Epoch 19/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.8285 - accuracy: 0.7037 - val_loss: 1.6163 - val_accuracy: 0.5101
# Epoch 20/20
# 56/56 [==============================] - 2s 27ms/step - loss: 0.8069 - accuracy: 0.7098 - val_loss: 1.6944 - val_accuracy: 0.5011

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 9, 9, 32)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2592)              0
#
#  dense_2 (Dense)             (None, 128)               331904
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 361,705
# Trainable params: 361,705
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Visualizing training results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_6 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_21 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_21 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_22 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 45, 45, 32)        9248
#
#  max_pooling2d_23 (MaxPoolin  (None, 22, 22, 32)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 22, 22, 64)        18496
#
#  max_pooling2d_24 (MaxPoolin  (None, 11, 11, 64)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten_5 (Flatten)         (None, 7744)              0
#
#  dense_10 (Dense)            (None, 128)               991360
#
#  dense_11 (Dense)            (None, 9)                 1161
#
# =================================================================
# Total params: 1,025,353
# Trainable params: 1,025,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 2s 28ms/step - loss: 2.0060 - accuracy: 0.2188 - val_loss: 1.9010 - val_accuracy: 0.2662
# Epoch 2/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.8687 - accuracy: 0.3209 - val_loss: 1.7706 - val_accuracy: 0.3356
# Epoch 3/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.7982 - accuracy: 0.3371 - val_loss: 1.7366 - val_accuracy: 0.3937
# Epoch 4/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.6836 - accuracy: 0.3996 - val_loss: 1.8459 - val_accuracy: 0.3423
# Epoch 5/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.5882 - accuracy: 0.4336 - val_loss: 1.4917 - val_accuracy: 0.4899
# Epoch 6/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4936 - accuracy: 0.4766 - val_loss: 1.4123 - val_accuracy: 0.5123
# Epoch 7/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4025 - accuracy: 0.5022 - val_loss: 1.5184 - val_accuracy: 0.5034
# Epoch 8/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4034 - accuracy: 0.4978 - val_loss: 1.4005 - val_accuracy: 0.5391
# Epoch 9/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3347 - accuracy: 0.5262 - val_loss: 1.3890 - val_accuracy: 0.5168
# Epoch 10/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2861 - accuracy: 0.5312 - val_loss: 1.4273 - val_accuracy: 0.5056
# Epoch 11/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3364 - accuracy: 0.5134 - val_loss: 1.3670 - val_accuracy: 0.5190
# Epoch 12/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2908 - accuracy: 0.5352 - val_loss: 1.4469 - val_accuracy: 0.5123
# Epoch 13/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3045 - accuracy: 0.5402 - val_loss: 1.3861 - val_accuracy: 0.5145
# Epoch 14/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2778 - accuracy: 0.5340 - val_loss: 1.3135 - val_accuracy: 0.5280
# Epoch 15/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2321 - accuracy: 0.5575 - val_loss: 1.4849 - val_accuracy: 0.5101
# Epoch 16/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2163 - accuracy: 0.5530 - val_loss: 1.3808 - val_accuracy: 0.5369
# Epoch 17/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2098 - accuracy: 0.5597 - val_loss: 1.3398 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1908 - accuracy: 0.5698 - val_loss: 1.4372 - val_accuracy: 0.5034
# Epoch 19/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1935 - accuracy: 0.5586 - val_loss: 1.2790 - val_accuracy: 0.5682
# Epoch 20/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1177 - accuracy: 0.5910 - val_loss: 1.2825 - val_accuracy: 0.5682

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
